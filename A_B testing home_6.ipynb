# %% [markdown]
# ### Задание 1. Продакт на главной mail.ru решил протестировать в рекомендательной ленте контента вместо карточек со статьями видеоплеер с короткими видео. Нынешний таймспент на юзера в день в среднем равен 25 минут, а стандартная ошибка (SD) равна 156.                                                                          Мы предполагаем, что в новой версии таймспент на юзера в день изменится на 10%. Средний трафик 20000 человек в день.                                                                                                                                                  Посчитайте сколько дней необходимо держать эксперимент при alpha = 5% и beta = 20% .

# %% [markdown]
# #### Таймспент А равен 25 минут, таймспент В равен 27,5 минут (25 + 25 * 10%).
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%D0%BE%D1%82%202024-02-05%2016-09-30.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%D0%BE%D1%82%202024-02-05%2016-09-30.png)

# %% [markdown]
# #### Для проведения тестирования необходимо 61124 юзера в каждой группе (т.е. 122248 всего на два потока) . С учетом среднего трафика 20000 человек в день, тест необходимо продержать минимум 6 дней.

# %% [markdown]
# ### Задание 2. Наша продуктовая команда в ecommerce магазине планирует запустить тест, направленный на ускорение загрузки сайта. Одна из основных метрик bounce rate в GA = 40%. Мы предполагаем, что при оптимизации сайта она изменится минимум на 20%.Средний трафик 4000 человек в день. Посчитайте сколько нам нужно дней держать эксперимент при alpha = 5% и beta = 20%

# %% [markdown]
# #### Bounce rate это процент отказов посетителей магазина от каких-либо действий на странице магазина. Продуктовая команда предполагает, что ускорение загрузки сайта приведет к изменению bounce rate на 20% (от изначального значения).
# #### Bounce rate A = 40%, bounse rate B = 20%
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%D0%BE%D1%82%202024-02-05%2017-03-41.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%D0%BE%D1%82%202024-02-05%2017-03-41.png)

# %% [markdown]
# #### Таким образом общее количество пользователей необходимых для тестирование равно 1184. При среднем трафике в 4000 человек в день, количество дней для проведения тестирования будет менее одного дня, точнее около 7 - 8 часов.
